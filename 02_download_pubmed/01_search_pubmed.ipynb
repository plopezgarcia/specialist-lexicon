# %% [markdown]
# # 1. Descarga Pubmed
# ### Hacemos una consulta por cada especialidad para obtener los IDs de los documentos de PubMed

# %%
import os
from Bio import Entrez
from urllib.request import urlopen

# %%
path_file_queries = 'total_queries.txt'
path_files_xmls = 'specialties_subespecialties_xml'
path_casesreports_xml = 'specialties_subespecialties_case_report_xml'
url_entrez = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&retmode=xml&id='

# %%
def open_url(url, file):
    try:
        xml = open(file, "a+")
        xml.write(urlopen(url).read().decode('utf-8'))
        xml.close()
    except urllib.error.HTTPError:
        print("**** URL demasiado larga")

# %%
def search_pubmed(query):
    Entrez.email = 'email@email.com'
    handle = Entrez.esearch(db='pubmed', 
                            sort='relevance', 
                            retmax='1000000',
                            retmode='xml', 
                            term=query)
    
    results = Entrez.read(handle)
    return results

# %%
def download_xmls(list_pmid, file_output):
    if len(list_pmid) < 400:

        url = ','.join(list_pmid)
        url_search = url_entrez + url

        print('[{}/{}]'.format(len(list_pmid), len(list_pmid)))

        open_url(url_search, file_output)

    else:
        
        # hacemos peripecias para hacer la llamada a la URL
        # creamos un fichero auxiliar para albergar varias llamadas a la URL
        new_list_pmid = [list_pmid[i:i+400] for i in range(0, len(list_pmid), 400)]

        for pos, list_files in enumerate(new_list_pmid):

            url = ','.join(list_files)
            url_search = url_entrez + url

            print('[{}/{}]'.format(pos, len(new_list_pmid)))

            open_url(url_search, file_output.replace(".xml", ".mal"))
    
        # construímos el fichero correcto 
        with open(file_output.replace(".xml", ".mal"),"r") as f:
            content = f.read()
            content = content.replace('</PubmedArticleSet><?xml version="1.0" ?>\n<!DOCTYPE PubmedArticleSet PUBLIC "-//NLM//DTD PubMedArticle, 1st January 2019//EN" "https://dtd.nlm.nih.gov/ncbi/pubmed/out/pubmed_190101.dtd">\n<PubmedArticleSet>', '')
            with open(file_output, 'w') as f:
                f.write(content)

# %%
def read_file_queries():
    with open(path_file_queries, 'r') as fquery:
        
        for index, line in enumerate(fquery):
            line = line.strip()
            
            # contruímos un buen nombre para el documento
            tree_num = line.split("#")[0]
            specialty = line.split("#")[1]
            specialty = specialty.lower()
            specialty = specialty.replace(", ", " ")
            specialty = specialty.replace(" ", "_")
            specialty = specialty.replace("-", "_")
            
            specialty = tree_num + '_' + specialty
            query = line.split("#")[2]
            
            # comprobamos que no esté generado anteriormente
            if not os.path.isfile(os.path.join(path_files_xmls, specialty) + '.xml'):
                
                # query normal (sin cases reports)
                normal_query = query + ' and not Case Reports[PT]'
                
                # query para obtener los cases reports
                case_report_query = query + ' and Case Reports[PT]'
                
                results_total = search_pubmed(query)
                results_files = search_pubmed(normal_query)
                results_cr = search_pubmed(case_report_query)
                
                list_pmid_total = results_total['IdList']
                list_pmid_files = results_files['IdList']
                list_pmid_cr = results_cr['IdList']
                
                # comprobamos que: numFilesSinCasesReports + numFilesCasesReports = numFilesTotal
                print("{} - {}, nº doc total: {}, files: {}, cases reports: {}. -> {}".format(index, specialty, 
                                                                                        len(list_pmid_total), 
                                                                                        len(list_pmid_files), 
                                                                                        len(list_pmid_cr),
                                                                                        len(list_pmid_files) + len(list_pmid_cr) == len(list_pmid_total)    
                                                                                            ))
                if len(list_pmid_total) > 10000:

                    #DOWNLOAD NORMAL PUBLICATION
                    print("Download normal publication type.")
                    file_output = os.path.join(path_files_xmls, specialty) + '.xml'
                    download_xmls(list_pmid_files, file_output)

                    #DOWNLOAD CASES REPORTS
                    print("Download cases reports publication type.")
                    file_output = os.path.join(path_casesreports_xml, specialty) + '.xml'
                    download_xmls(list_pmid_cr, file_output)

# %%
read_file_queries()
# Out:
# 0 - H02.403.225_dermatology, nº doc total: 18374, files: 10766, cases reports: 7608. -> True
# Download normal publication type.
# [0/27]
# [1/27]
# [2/27]
# [3/27]
# [4/27]
# [5/27]
# [6/27]
# [7/27]
# [8/27]
# [9/27]
# [10/27]
# [11/27]
# [12/27]
# [13/27]
# [14/27]
# [15/27]
# [16/27]
# [17/27]
# [18/27]
# [19/27]
# [20/27]
# [21/27]
# [22/27]
# [23/27]
# [24/27]
# [25/27]
# [26/27]
# Download cases reports publication type.
# [0/20]
# [1/20]
# [2/20]
# [3/20]
# [4/20]
# [5/20]
# [6/20]
# [7/20]
# [8/20]
# [9/20]
# [10/20]
# [11/20]
# [12/20]
# [13/20]
# [14/20]
# [15/20]
# [16/20]
# [17/20]
# [18/20]
# [19/20]
# 1 - H02.403.720.500_epidemiology, nº doc total: 35329, files: 34403, cases reports: 926. -> True
# Download normal publication type.
# [0/87]
# [1/87]
# [2/87]
# [3/87]
# [4/87]
# [5/87]
# [6/87]
# [7/87]
# [8/87]
# [9/87]
# [10/87]
# [11/87]
# [12/87]
# [13/87]
# [14/87]
# [15/87]
# [16/87]
# [17/87]
# [18/87]
# [19/87]
# [20/87]
# [21/87]
# [22/87]
# [23/87]
# [24/87]
# [25/87]
# [26/87]
# [27/87]
# [28/87]
# [29/87]
# [30/87]
# [31/87]
# [32/87]
# [33/87]
# [34/87]
# [35/87]
# [36/87]
# [37/87]
# [38/87]
# [39/87]
# [40/87]
# [41/87]
# [42/87]
# [43/87]
# [44/87]
# [45/87]
# [46/87]
# [47/87]
# [48/87]
# [49/87]
# [50/87]
# [51/87]
# [52/87]
# [53/87]
# [54/87]
# [55/87]
# [56/87]
# [57/87]
# [58/87]
# [59/87]
# [60/87]
# [61/87]
# [62/87]
# [63/87]
# [64/87]
# [65/87]
# [66/87]
# [67/87]
# [68/87]
# [69/87]
# [70/87]
# [71/87]
# [72/87]
# [73/87]
# [74/87]
# [75/87]
# [76/87]
# [77/87]
# [78/87]
# [79/87]
# [80/87]
# [81/87]
# [82/87]
# [83/87]
# [84/87]
# [85/87]
# [86/87]
# Download cases reports publication type.
# [0/3]
# [1/3]
# [2/3]
# 2 - H02.403.720.750_preventive_medicine, nº doc total: 97141, files: 89145, cases reports: 7996. -> True
# Download normal publication type.
# [0/223]
# [1/223]
# [2/223]
# [3/223]
# [4/223]
# [5/223]
# [6/223]
# [7/223]
# [8/223]
# [9/223]
# [10/223]
# [11/223]
# [12/223]
# [13/223]
# [14/223]
# [15/223]
# [16/223]
# [17/223]
# [18/223]
# [19/223]
# [20/223]
# [21/223]
# [22/223]
# [23/223]
# [24/223]
# [25/223]
# [26/223]
# [27/223]
# [28/223]
# [29/223]
# [30/223]
# [31/223]
# [32/223]
# [33/223]
# [34/223]
# [35/223]
# [36/223]
# [37/223]
# [38/223]
# [39/223]
# [40/223]
# [41/223]
# [42/223]
# [43/223]
# [44/223]
# [45/223]
# [46/223]
# [47/223]
# [48/223]
# [49/223]
# [50/223]
# [51/223]
# [52/223]
# [53/223]
# [54/223]
# [55/223]
# [56/223]
# [57/223]
# [58/223]
# [59/223]
# [60/223]
# [61/223]
# [62/223]
# [63/223]
# [64/223]
# [65/223]
# [66/223]
# [67/223]
# [68/223]
# [69/223]
# [70/223]
# [71/223]
# [72/223]
# [73/223]
# [74/223]
# [75/223]
# [76/223]
# [77/223]
# [78/223]
# [79/223]
# [80/223]
# [81/223]
# [82/223]
# [83/223]
# [84/223]
# [85/223]
# [86/223]
# [87/223]
# [88/223]
# [89/223]
# [90/223]
# [91/223]
# [92/223]
# [93/223]
# [94/223]
# [95/223]
# [96/223]
# [97/223]
# [98/223]
# [99/223]
# [100/223]
# [101/223]
# [102/223]
# [103/223]
# [104/223]
# [105/223]
# [106/223]
# [107/223]
# [108/223]
# [109/223]
# [110/223]
# [111/223]
# [112/223]
# [113/223]
# [114/223]
# [115/223]
# [116/223]
# [117/223]
# [118/223]
# [119/223]
# [120/223]
# [121/223]
# [122/223]
# [123/223]
# [124/223]
# [125/223]
# [126/223]
# [127/223]
# [128/223]
# [129/223]
# [130/223]
# [131/223]
# [132/223]
# [133/223]
# [134/223]
# [135/223]
# [136/223]
# [137/223]
# [138/223]
# [139/223]
# [140/223]
# [141/223]
# [142/223]
# [143/223]
# [144/223]
# [145/223]
# [146/223]
# [147/223]
# [148/223]
# [149/223]
# [150/223]
# [151/223]
# [152/223]
# [153/223]
# [154/223]
# [155/223]
# [156/223]
# [157/223]
# [158/223]
# [159/223]
# [160/223]
# [161/223]
# [162/223]
# [163/223]
# [164/223]
# [165/223]
# [166/223]
# [167/223]
# [168/223]
# [169/223]
# [170/223]
# [171/223]
# [172/223]
# [173/223]
# [174/223]
# [175/223]
# [176/223]
# [177/223]
# [178/223]
# [179/223]
# [180/223]
# [181/223]
# [182/223]
# [183/223]
# [184/223]
# [185/223]
# [186/223]
# [187/223]
# [188/223]
# [189/223]
# [190/223]
# [191/223]
# [192/223]
# [193/223]
# [194/223]
# [195/223]
# [196/223]
# [197/223]
# [198/223]
# [199/223]
# [200/223]
# [201/223]
# [202/223]
# [203/223]
# [204/223]
# [205/223]
# [206/223]
# [207/223]
# [208/223]
# [209/223]
# [210/223]
# [211/223]
# [212/223]
# [213/223]
# [214/223]
# [215/223]
# [216/223]
# [217/223]
# [218/223]
# [219/223]
# [220/223]
# [221/223]
# [222/223]
# Download cases reports publication type.
# [0/20]
# [1/20]
# [2/20]
# [3/20]
# [4/20]
# [5/20]
# [6/20]
# [7/20]
# [8/20]
# [9/20]
# [10/20]
# [11/20]
# [12/20]
# [13/20]
# [14/20]
# [15/20]
# [16/20]
# [17/20]
# [18/20]
# [19/20]
# 17 - H02.403.429.515_medical_oncology, nº doc total: 45235, files: 27772, cases reports: 17463. -> True
# Download normal publication type.
# [0/70]
# [1/70]
# [2/70]
# [3/70]
# [4/70]
# [5/70]
# [6/70]
# [7/70]
# [8/70]
# [9/70]
# [10/70]
# [11/70]
# [12/70]
# [13/70]
# [14/70]
# [15/70]
# [16/70]
# [17/70]
# [18/70]
# [19/70]
# [20/70]
# [21/70]
# [22/70]
# [23/70]
# [24/70]
# [25/70]
# [26/70]
# [27/70]
# [28/70]
# [29/70]
# [30/70]
# [31/70]
# [32/70]
# [33/70]
# [34/70]
# [35/70]
# [36/70]
# [37/70]
# [38/70]
# [39/70]
# [40/70]
# [41/70]
# [42/70]
# [43/70]
# [44/70]
# [45/70]
# [46/70]
# [47/70]
# [48/70]
# [49/70]
# [50/70]
# [51/70]
# [52/70]
# [53/70]
# [54/70]
# [55/70]
# [56/70]
# [57/70]
# [58/70]
# [59/70]
# [60/70]
# [61/70]
# [62/70]
# [63/70]
# [64/70]
# [65/70]
# [66/70]
# [67/70]
# [68/70]
# [69/70]
# Download cases reports publication type.
# [0/44]
# [1/44]
# [2/44]
# [3/44]
# [4/44]
# [5/44]
# [6/44]
# [7/44]
# [8/44]
# [9/44]
# [10/44]
# [11/44]
# [12/44]
# [13/44]
# [14/44]
# [15/44]
# [16/44]
# [17/44]
# [18/44]
# [19/44]
# [20/44]
# [21/44]
# [22/44]
# [23/44]
# [24/44]
# [25/44]
# [26/44]
# [27/44]
# [28/44]
# [29/44]
# [30/44]
# [31/44]
# [32/44]
# [33/44]
# [34/44]
# [35/44]
# [36/44]
# [37/44]
# [38/44]
# [39/44]
# [40/44]
# [41/44]
# [42/44]
# [43/44]
# 18 - H02.403.600_neurology, nº doc total: 39154, files: 26009, cases reports: 13145. -> True
# Download normal publication type.
# [0/66]
# [1/66]
# [2/66]
# [3/66]
# [4/66]
# [5/66]
# [6/66]
# [7/66]
# [8/66]
# [9/66]
# [10/66]
# [11/66]
# [12/66]
# [13/66]
# [14/66]
# [15/66]
# [16/66]
# [17/66]
# [18/66]
# [19/66]
# [20/66]
# [21/66]
# [22/66]
# [23/66]
# [24/66]
# [25/66]
# [26/66]
# [27/66]
# [28/66]
# [29/66]
# [30/66]
# [31/66]
# [32/66]
# [33/66]
# [34/66]
# [35/66]
# [36/66]
# [37/66]
# [38/66]
# [39/66]
# [40/66]
# [41/66]
# [42/66]
# [43/66]
# [44/66]
# [45/66]
# [46/66]
# [47/66]
# [48/66]
# [49/66]
# [50/66]
# [51/66]
# [52/66]
# [53/66]
# [54/66]
# [55/66]
# [56/66]
# [57/66]
# [58/66]
# [59/66]
# [60/66]
# [61/66]
# [62/66]
# [63/66]
# [64/66]
# [65/66]
# Download cases reports publication type.
# [0/33]
# [1/33]
# [2/33]
# [3/33]
# [4/33]
# [5/33]
# [6/33]
# [7/33]
# [8/33]
# [9/33]
# [10/33]
# [11/33]
# [12/33]
# [13/33]
# [14/33]
# [15/33]
# [16/33]
# [17/33]
# [18/33]
# [19/33]
# [20/33]
# [21/33]
# [22/33]
# [23/33]
# [24/33]
# [25/33]
# [26/33]
# [27/33]
# [28/33]
# [29/33]
# [30/33]
# [31/33]
# [32/33]
# 20 - H02.403.650_pathology, nº doc total: 38458, files: 21884, cases reports: 16574. -> True
# Download normal publication type.
# [0/55]
# [1/55]
# [2/55]
# [3/55]
# [4/55]
# [5/55]
# [6/55]
# [7/55]
# [8/55]
# [9/55]
# [10/55]
# [11/55]
# [12/55]
# [13/55]
# [14/55]
# [15/55]
# [16/55]
# [17/55]
# [18/55]
# [19/55]
# [20/55]
# [21/55]
# [22/55]
# [23/55]
# [24/55]
# [25/55]
# [26/55]
# [27/55]
# [28/55]
# [29/55]
# [30/55]
# [31/55]
# [32/55]
# [33/55]
# [34/55]
# [35/55]
# [36/55]
# [37/55]
# [38/55]
# [39/55]
# [40/55]
# [41/55]
# [42/55]
# [43/55]
# [44/55]
# [45/55]
# [46/55]
# [47/55]
# [48/55]
# [49/55]
# [50/55]
# [51/55]
# [52/55]
# [53/55]
# [54/55]
# Download cases reports publication type.
# [0/42]
# [1/42]
# [2/42]
# [3/42]
# [4/42]
# [5/42]
# [6/42]
# [7/42]
# [8/42]
# [9/42]
# [10/42]
# [11/42]
# [12/42]
# [13/42]
# [14/42]
# [15/42]
# [16/42]
# [17/42]
# [18/42]
# [19/42]
# [20/42]
# [21/42]
# [22/42]
# [23/42]
# [24/42]
# [25/42]
# [26/42]
# [27/42]
# [28/42]
# [29/42]
# [30/42]
# [31/42]
# [32/42]
# [33/42]
# [34/42]
# [35/42]
# [36/42]
# [37/42]
# [38/42]
# [39/42]
# [40/42]
# [41/42]
# 22 - H02.403.720_public_health, nº doc total: 11108, files: 10963, cases reports: 145. -> True
# Download normal publication type.
# [0/28]
# [1/28]
# [2/28]
# [3/28]
# [4/28]
# [5/28]
# [6/28]
# [7/28]
# [8/28]
# [9/28]
# [10/28]
# [11/28]
# [12/28]
# [13/28]
# [14/28]
# [15/28]
# [16/28]
# [17/28]
# [18/28]
# [19/28]
# [20/28]
# [21/28]
# [22/28]
# [23/28]
# [24/28]
# [25/28]
# [26/28]
# [27/28]
# Download cases reports publication type.
# [145/145]
# 37 - H02.403.670.400_neonatology, nº doc total: 13683, files: 11533, cases reports: 2150. -> True
# Download normal publication type.
# [0/29]
# [1/29]
# [2/29]
# [3/29]
# [4/29]
# [5/29]
# [6/29]
# [7/29]
# [8/29]
# [9/29]
# [10/29]
# [11/29]
# [12/29]
# [13/29]
# [14/29]
# [15/29]
# [16/29]
# [17/29]
# [18/29]
# [19/29]
# [20/29]
# [21/29]
# [22/29]
# [23/29]
# [24/29]
# [25/29]
# [26/29]
# [27/29]
# [28/29]
# Download cases reports publication type.
# [0/6]
# [1/6]
# [2/6]
# [3/6]
# [4/6]
# [5/6]
# 38 - H02.403.810.300_general_surgery, nº doc total: 46318, files: 35211, cases reports: 11107. -> True
# Download normal publication type.
# [0/89]
# [1/89]
# [2/89]
# [3/89]
# [4/89]
# [5/89]
# [6/89]
# [7/89]
# [8/89]
# [9/89]
# [10/89]
# [11/89]
# [12/89]
# [13/89]
# [14/89]
# [15/89]
# [16/89]
# [17/89]
# [18/89]
# [19/89]
# [20/89]
# [21/89]
# [22/89]
# [23/89]
# [24/89]
# [25/89]
# [26/89]
# [27/89]
# [28/89]
# [29/89]
# [30/89]
# [31/89]
# [32/89]
# [33/89]
# [34/89]
# [35/89]
# [36/89]
# [37/89]
# [38/89]
# [39/89]
# [40/89]
# [41/89]
# [42/89]
# [43/89]
# [44/89]
# [45/89]
# [46/89]
# [47/89]
# [48/89]
# [49/89]
# [50/89]
# [51/89]
# [52/89]
# [53/89]
# [54/89]
# [55/89]
# [56/89]
# [57/89]
# [58/89]
# [59/89]
# [60/89]
# [61/89]
# [62/89]
# [63/89]
# [64/89]
# [65/89]
# [66/89]
# [67/89]
# [68/89]
# [69/89]
# [70/89]
# [71/89]
# [72/89]
# [73/89]
# [74/89]
# [75/89]
# [76/89]
# [77/89]
# [78/89]
# [79/89]
# [80/89]
# [81/89]
# [82/89]
# [83/89]
# [84/89]
# [85/89]
# [86/89]
# [87/89]
# [88/89]
# Download cases reports publication type.
# [0/28]
# [1/28]
# [2/28]
# [3/28]
# [4/28]
# [5/28]
# [6/28]
# [7/28]
# [8/28]
# [9/28]
# [10/28]
# [11/28]
# [12/28]
# [13/28]
# [14/28]
# [15/28]
# [16/28]
# [17/28]
# [18/28]
# [19/28]
# [20/28]
# [21/28]
# [22/28]
# [23/28]
# [24/28]
# [25/28]
# [26/28]
# [27/28]
# 40 - H02.403.810.850_traumatology, nº doc total: 10238, files: 6731, cases reports: 3507. -> True
# Download normal publication type.
# [0/17]
# [1/17]
# [2/17]
# [3/17]
# [4/17]
# [5/17]
# [6/17]
# [7/17]
# [8/17]
# [9/17]
# [10/17]
# [11/17]
# [12/17]
# [13/17]
# [14/17]
# [15/17]
# [16/17]
# Download cases reports publication type.
# [0/9]
# [1/9]
# [2/9]
# [3/9]
# [4/9]
# [5/9]
# [6/9]
# [7/9]
# [8/9]
# 41 - H02.403.810.860_urology, nº doc total: 22643, files: 15509, cases reports: 7134. -> True
# Download normal publication type.
# [0/39]
# [1/39]
# [2/39]
# [3/39]
# [4/39]
# [5/39]
# [6/39]
# [7/39]
# [8/39]
# [9/39]
# [10/39]
# [11/39]
# [12/39]
# [13/39]
# [14/39]
# [15/39]
# [16/39]
# [17/39]
# [18/39]
# [19/39]
# [20/39]
# [21/39]
# [22/39]
# [23/39]
# [24/39]
# [25/39]
# [26/39]
# [27/39]
# [28/39]
# [29/39]
# [30/39]
# [31/39]
# [32/39]
# [33/39]
# [34/39]
# [35/39]
# [36/39]
# [37/39]
# [38/39]
# Download cases reports publication type.
# [0/18]
# [1/18]
# [2/18]
# [3/18]
# [4/18]
# [5/18]
# [6/18]
# [7/18]
# [8/18]
# [9/18]
# [10/18]
# [11/18]
# [12/18]
# [13/18]
# [14/18]
# [15/18]
# [16/18]
# [17/18]
# 61 - H02.403.350_genetics_medical, nº doc total: 11682, files: 6943, cases reports: 4739. -> True
# Download normal publication type.
# [0/18]
# [1/18]
# [2/18]
# [3/18]
# [4/18]
# [5/18]
# [6/18]
# [7/18]
# [8/18]
# [9/18]
# [10/18]
# [11/18]
# [12/18]
# [13/18]
# [14/18]
# [15/18]
# [16/18]
# [17/18]
# Download cases reports publication type.
# [0/12]
# [1/12]
# [2/12]
# [3/12]
# [4/12]
# [5/12]
# [6/12]
# [7/12]
# [8/12]
# [9/12]
# [10/12]
# [11/12]
# 71 - H02.403.429.163_cardiology, nº doc total: 43623, files: 31209, cases reports: 12414. -> True
# Download normal publication type.
# [0/79]
# [1/79]
# [2/79]
# [3/79]
# [4/79]
# [5/79]
# [6/79]
# [7/79]
# [8/79]
# [9/79]
# [10/79]
# [11/79]
# [12/79]
# [13/79]
# [14/79]
# [15/79]
# [16/79]
# [17/79]
# [18/79]
# [19/79]
# [20/79]
# [21/79]
# [22/79]
# [23/79]
# [24/79]
# [25/79]
# [26/79]
# [27/79]
# [28/79]
# [29/79]
# [30/79]
# [31/79]
# [32/79]
# [33/79]
# [34/79]
# [35/79]
# [36/79]
# [37/79]
# [38/79]
# [39/79]
# [40/79]
# [41/79]
# [42/79]
# [43/79]
# [44/79]
# [45/79]
# [46/79]
# [47/79]
# [48/79]
# [49/79]
# [50/79]
# [51/79]
# [52/79]
# [53/79]
# [54/79]
# [55/79]
# [56/79]
# [57/79]
# [58/79]
# [59/79]
# [60/79]
# [61/79]
# [62/79]
# [63/79]
# [64/79]
# [65/79]
# [66/79]
# [67/79]
# [68/79]
# [69/79]
# [70/79]
# [71/79]
# [72/79]
# [73/79]
# [74/79]
# [75/79]
# [76/79]
# [77/79]
# [78/79]
# Download cases reports publication type.
# [0/32]
# [1/32]
# [2/32]
# [3/32]
# [4/32]
# [5/32]
# [6/32]
# [7/32]
# [8/32]
# [9/32]
# [10/32]
# [11/32]
# [12/32]
# [13/32]
# [14/32]
# [15/32]
# [16/32]
# [17/32]
# [18/32]
# [19/32]
# [20/32]
# [21/32]
# [22/32]
# [23/32]
# [24/32]
# [25/32]
# [26/32]
# [27/32]
# [28/32]
# [29/32]
# [30/32]
# [31/32]
# 79 - H02.403.200_clinical_medicine, nº doc total: 21662, files: 15909, cases reports: 5753. -> True
# Download normal publication type.
# [0/40]
# [1/40]
# [2/40]
# [3/40]
# [4/40]
# [5/40]
# [6/40]
# [7/40]
# [8/40]
# [9/40]
# [10/40]
# [11/40]
# [12/40]
# [13/40]
# [14/40]
# [15/40]
# [16/40]
# [17/40]
# [18/40]
# [19/40]
# [20/40]
# [21/40]
# [22/40]
# [23/40]
# [24/40]
# [25/40]
# [26/40]
# [27/40]
# [28/40]
# [29/40]
# [30/40]
# [31/40]
# [32/40]
# [33/40]
# [34/40]
# [35/40]
# [36/40]
# [37/40]
# [38/40]
# [39/40]
# Download cases reports publication type.
# [0/15]
# [1/15]
# [2/15]
# [3/15]
# [4/15]
# [5/15]
# [6/15]
# [7/15]
# [8/15]
# [9/15]
# [10/15]
# [11/15]
# [12/15]
# [13/15]
# [14/15]
# 87 - H02.403.429.323_endocrinology, nº doc total: 18408, files: 13062, cases reports: 5346. -> True
# Download normal publication type.
# [0/33]
# [1/33]
# [2/33]
# [3/33]
# [4/33]
# [5/33]
# [6/33]
# [7/33]
# [8/33]
# [9/33]
# [10/33]
# [11/33]
# [12/33]
# [13/33]
# [14/33]
# [15/33]
# [16/33]
# [17/33]
# [18/33]
# [19/33]
# [20/33]
# [21/33]
# [22/33]
# [23/33]
# [24/33]
# [25/33]
# [26/33]
# [27/33]
# [28/33]
# [29/33]
# [30/33]
# [31/33]
# [32/33]
# Download cases reports publication type.
# [0/14]
# [1/14]
# [2/14]
# [3/14]
# [4/14]
# [5/14]
# [6/14]
# [7/14]
# [8/14]
# [9/14]
# [10/14]
# [11/14]
# [12/14]
# [13/14]
# 90 - H02.403.429.405_gastroenterology, nº doc total: 24320, files: 16830, cases reports: 7490. -> True
# Download normal publication type.
# [0/43]
# [1/43]
# [2/43]
# [3/43]
# [4/43]
# [5/43]
# [6/43]
# [7/43]
# [8/43]
# [9/43]
# [10/43]
# [11/43]
# [12/43]
# [13/43]
# [14/43]
# [15/43]
# [16/43]
# [17/43]
# [18/43]
# [19/43]
# [20/43]
# [21/43]
# [22/43]
# [23/43]
# [24/43]
# [25/43]
# [26/43]
# [27/43]
# [28/43]
# [29/43]
# [30/43]
# [31/43]
# [32/43]
# [33/43]
# [34/43]
# [35/43]
# [36/43]
# [37/43]
# [38/43]
# [39/43]
# [40/43]
# [41/43]
# [42/43]
# Download cases reports publication type.
# [0/19]
# [1/19]
# [2/19]
# [3/19]
# [4/19]
# [5/19]
# [6/19]
# [7/19]
# [8/19]
# [9/19]
# [10/19]
# [11/19]
# [12/19]
# [13/19]
# [14/19]
# [15/19]
# [16/19]
# [17/19]
# [18/19]
# 92 - H02.403.355_geriatrics, nº doc total: 51616, files: 37840, cases reports: 13776. -> True
# Download normal publication type.
# [0/95]
# [1/95]
# [2/95]
# [3/95]
# [4/95]
# [5/95]
# [6/95]
# [7/95]
# [8/95]
# [9/95]
# [10/95]
# [11/95]
# [12/95]
# [13/95]
# [14/95]
# [15/95]
# [16/95]
# [17/95]
# [18/95]
# [19/95]
# [20/95]
# [21/95]
# [22/95]
# [23/95]
# [24/95]
# [25/95]
# [26/95]
# [27/95]
# [28/95]
# [29/95]
# [30/95]
# [31/95]
# [32/95]
# [33/95]
# [34/95]
# [35/95]
# [36/95]
# [37/95]
# [38/95]
# [39/95]
# [40/95]
# [41/95]
# [42/95]
# [43/95]
# [44/95]
# [45/95]
# [46/95]
# [47/95]
# [48/95]
# [49/95]
# [50/95]
# [51/95]
# [52/95]
# [53/95]
# [54/95]
# [55/95]
# [56/95]
# [57/95]
# [58/95]
# [59/95]
# [60/95]
# [61/95]
# [62/95]
# [63/95]
# [64/95]
# [65/95]
# [66/95]
# [67/95]
# [68/95]
# [69/95]
# [70/95]
# [71/95]
# [72/95]
# [73/95]
# [74/95]
# [75/95]
# [76/95]
# [77/95]
# [78/95]
# [79/95]
# [80/95]
# [81/95]
# [82/95]
# [83/95]
# [84/95]
# [85/95]
# [86/95]
# [87/95]
# [88/95]
# [89/95]
# [90/95]
# [91/95]
# [92/95]
# [93/95]
# [94/95]
# Download cases reports publication type.
# [0/35]
# [1/35]
# [2/35]
# [3/35]
# [4/35]
# [5/35]
# [6/35]
# [7/35]
# [8/35]
# [9/35]
# [10/35]
# [11/35]
# [12/35]
# [13/35]
# [14/35]
# [15/35]
# [16/35]
# [17/35]
# [18/35]
# [19/35]
# [20/35]
# [21/35]
# [22/35]
# [23/35]
# [24/35]
# [25/35]
# [26/35]
# [27/35]
# [28/35]
# [29/35]
# [30/35]
# [31/35]
# [32/35]
# [33/35]
# [34/35]
# 93 - H02.403.763.750_gynecology, nº doc total: 10354, files: 8601, cases reports: 1753. -> True
# Download normal publication type.
# [0/22]
# [1/22]
# [2/22]
# [3/22]
# [4/22]
# [5/22]
# [6/22]
# [7/22]
# [8/22]
# [9/22]
# [10/22]
# [11/22]
# [12/22]
# [13/22]
# [14/22]
# [15/22]
# [16/22]
# [17/22]
# [18/22]
# [19/22]
# [20/22]
# [21/22]
# Download cases reports publication type.
# [0/5]
# [1/5]
# [2/5]
# [3/5]
# [4/5]
# 94 - H02.403.810.310_gynecology, nº doc total: 10354, files: 8601, cases reports: 1753. -> True
# Download normal publication type.
# [0/22]
# [1/22]
# [2/22]
# [3/22]
# [4/22]
# [5/22]
# [6/22]
# [7/22]
# [8/22]
# [9/22]
# [10/22]
# [11/22]
# [12/22]
# [13/22]
# [14/22]
# [15/22]
# [16/22]
# [17/22]
# [18/22]
# [19/22]
# [20/22]
# [21/22]
# Download cases reports publication type.
# [0/5]
# [1/5]
# [2/5]
# [3/5]
# [4/5]
# 95 - H02.403.429.445_hematology, nº doc total: 12441, files: 7687, cases reports: 4754. -> True
# Download normal publication type.
# [0/20]
# [1/20]
# [2/20]
# [3/20]
# [4/20]
# [5/20]
# [6/20]
# [7/20]
# [8/20]
# [9/20]
# [10/20]
# [11/20]
# [12/20]
# [13/20]
# [14/20]
# [15/20]
# [16/20]
# [17/20]
# [18/20]
# [19/20]
# Download cases reports publication type.
# [0/12]
# [1/12]
# [2/12]
# [3/12]
# [4/12]
# [5/12]
# [6/12]
# [7/12]
# [8/12]
# [9/12]
# [10/12]
# [11/12]
# 104 - H02.403.429.580_nephrology, nº doc total: 12909, files: 8750, cases reports: 4159. -> True
# Download normal publication type.
# [0/22]
# [1/22]
# [2/22]
# [3/22]
# [4/22]
# [5/22]
# [6/22]
# [7/22]
# [8/22]
# [9/22]
# [10/22]
# [11/22]
# [12/22]
# [13/22]
# [14/22]
# [15/22]
# [16/22]
# [17/22]
# [18/22]
# [19/22]
# [20/22]
# [21/22]
# Download cases reports publication type.
# [0/11]
# [1/11]
# [2/11]
# [3/11]
# [4/11]
# [5/11]
# [6/11]
# [7/11]
# [8/11]
# [9/11]
# [10/11]
# 106 - H02.403.810.450_obstetrics, nº doc total: 11460, files: 9548, cases reports: 1912. -> True
# Download normal publication type.
# [0/24]
# [1/24]
# [2/24]
# [3/24]
# [4/24]
# [5/24]
# [6/24]
# [7/24]
# [8/24]
# [9/24]
# [10/24]
# [11/24]
# [12/24]
# [13/24]
# [14/24]
# [15/24]
# [16/24]
# [17/24]
# [18/24]
# [19/24]
# [20/24]
# [21/24]
# [22/24]
# [23/24]
# Download cases reports publication type.
# [0/5]
# [1/5]
# [2/5]
# [3/5]
# [4/5]
# 115 - H02.403.670.500_perinatology, nº doc total: 11798, files: 9571, cases reports: 2227. -> True
# Download normal publication type.
# [0/24]
# [1/24]
# [2/24]
# [3/24]
# [4/24]
# [5/24]
# [6/24]
# [7/24]
# [8/24]
# [9/24]
# [10/24]
# [11/24]
# [12/24]
# [13/24]
# [14/24]
# [15/24]
# [16/24]
# [17/24]
# [18/24]
# [19/24]
# [20/24]
# [21/24]
# [22/24]
# [23/24]
# Download cases reports publication type.
# [0/6]
# [1/6]
# [2/6]
# [3/6]
# [4/6]
# [5/6]
