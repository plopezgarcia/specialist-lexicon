# %% [markdown]
# # 1. Crear dataframe por especialidad -
# ### Directorio: df_specialty_title_abstract
# ### Columnas dataframe: (id, title_spa, abstract_spa)

# %%
import os
import xml.etree.ElementTree as ET
import pandas as pd

# %%
path_pubmed_xml_specialties = '../02_download_pubmed/specialties_case_report_xml/'
path_df_specialty_title_abstract = './dataframes/df_specialty_title_abstract_case_report'

# %%
def get_lists_pmid_title_abstract(root):
    
    list_pmid = []
    list_title = []
    list_abstract = []
    
    for PubmedArticle in root.findall('PubmedArticle'):
        
        pmid = ''
        title_spa = ''
        abstract_spa = ''
        
        for MedlineCitation in PubmedArticle.findall('MedlineCitation'):
            pmid = MedlineCitation.find('PMID').text
        
            for Article in MedlineCitation.findall('Article'):
                if not Article.find('VernacularTitle') is None:              
                    title_spa = Article.find('VernacularTitle').text
                    
                    if not title_spa is None and len(title_spa) > 1 and title_spa.isupper():
                        title_spa = title_spa.replace("'A", "Á")
                        title_spa = title_spa.replace("'E", "É")
                        title_spa = title_spa.replace("'I", "Í")
                        title_spa = title_spa.replace("'O", "Ó")
                        title_spa = title_spa.replace("'U", "Ú")
                        
            
            for OtherAbstract in MedlineCitation.findall('OtherAbstract'):
                abstrac_lang = OtherAbstract.get('Language')
                                
                if abstrac_lang == 'spa':
                    for AbstractText in OtherAbstract.findall('AbstractText'):
                        if not AbstractText.text is None:
                            abstract_spa = abstract_spa + AbstractText.text + ' '
        
        if not title_spa is None and len(title_spa) > 1: 
            list_pmid.append(pmid)
            list_title.append(title_spa)
            list_abstract.append(abstract_spa)
        
    print(len(list_pmid), len(list_title), len(list_abstract))  
    
    return list_pmid, list_title, list_abstract

# %%
def read_xml_file(file_xml):
    tree = ET.parse(file_xml)
    root = tree.getroot()
    return root

# %%
def create_dataframe_text_abstract(specialty_name, specialty_xml):
    
    xml_data = read_xml_file(specialty_xml)
    
    #pmid = get_pmid(xml_data)
    list_pmid, list_title, list_abstract = get_lists_pmid_title_abstract(xml_data)
    
    df = pd.DataFrame ( { 'id': list_pmid, 'title': list_title, 'abstract': list_abstract})
    df.to_csv(os.path.join(path_df_specialty_title_abstract, specialty_name) + '.csv')

    print("Guardado ", os.path.join(path_df_specialty_title_abstract, specialty_name) + '.csv' , ' Long: ', len(df))

# %%
def read_path_specialties_xml():
    
    for root, dirs, list_files in os.walk(path_pubmed_xml_specialties):
        for specialty in list_files:
            specialty_name = specialty.split(".xml")[0]
            
            print(specialty_name)

            create_dataframe_text_abstract(specialty_name, root + specialty)

# %%
read_path_specialties_xml()
# Out:
# H02.403.810.494_orthopedics
# 515 515 515
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.810.494_orthopedics.csv  Long:  515
# H02.403.350_genetics_medical
# 4416 4416 4416
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.350_genetics_medical.csv  Long:  4416
# H02.403.645_palliative_medicine
# 104 104 104
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.645_palliative_medicine.csv  Long:  104
# H02.403.879_tropical_medicine
# 88 88 88
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.879_tropical_medicine.csv  Long:  88
# H02.403.429.675_pulmonary_medicine
# 530 530 530
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.429.675_pulmonary_medicine.csv  Long:  530
# H02.403.429.480_infectious_disease_medicine
# 257 257 257
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.429.480_infectious_disease_medicine.csv  Long:  257
# H02.403.720.750_preventive_medicine
# 7195 7195 7195
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.720.750_preventive_medicine.csv  Long:  7195
# H02.403.670.400_neonatology
# 2084 2084 2084
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.670.400_neonatology.csv  Long:  2084
# H02.403.429_internal_medicine
# 2520 2520 2520
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.429_internal_medicine.csv  Long:  2520
# H02.403.690.150_community_psychiatry
# 120 120 120
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.690.150_community_psychiatry.csv  Long:  120
# H02.403.830_sports_medicine
# 102 102 102
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.830_sports_medicine.csv  Long:  102
# H02.403.810.450_obstetrics
# 1821 1821 1821
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.810.450_obstetrics.csv  Long:  1821
# H02.403.500_military_medicine
# 1 1 1
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.500_military_medicine.csv  Long:  1
# H02.403.600_neurology
# 12560 12560 12560
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.600_neurology.csv  Long:  12560
# H02.403.429.405_gastroenterology
# 7019 7019 7019
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.429.405_gastroenterology.csv  Long:  7019
# H02.403.810.803_thoracic_surgery
# 1691 1691 1691
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.810.803_thoracic_surgery.csv  Long:  1691
# H02.403.429.445_hematology
# 4541 4541 4541
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.429.445_hematology.csv  Long:  4541
# H02.403.810_specialties_surgical
# 28 28 28
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.810_specialties_surgical.csv  Long:  28
# H02.403.044.500_immunochemistry
# 838 838 838
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.044.500_immunochemistry.csv  Long:  838
# H02.403.650_pathology
# 15619 15619 15619
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.650_pathology.csv  Long:  15619
# H02.403.429.515_medical_oncology
# 16154 16154 16154
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.429.515_medical_oncology.csv  Long:  16154
# H02.403.690_psychiatry
# 190 190 190
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.690_psychiatry.csv  Long:  190
# H02.403.340_general_practice
# 9 9 9
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.340_general_practice.csv  Long:  9
# H02.403.763_reproductive_medicine
# 87 87 87
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.763_reproductive_medicine.csv  Long:  87
# H02.403.044_allergy_and_immunology
# 36 36 36
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.044_allergy_and_immunology.csv  Long:  36
# H02.403.330_forensic_medicine
# 17 17 17
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.330_forensic_medicine.csv  Long:  17
# H02.403.074_bariatric_medicine
# 68 68 68
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.074_bariatric_medicine.csv  Long:  68
# H02.403.909_venereology
# 1600 1600 1600
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.909_venereology.csv  Long:  1600
# H02.403.066_anesthesiology
# 810 810 810
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.066_anesthesiology.csv  Long:  810
# H02.403.810.300_general_surgery
# 10141 10141 10141
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.810.300_general_surgery.csv  Long:  10141
# H02.403.740_radiology
# 870 870 870
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.740_radiology.csv  Long:  870
# H02.403.810.468_ophthalmology
# 2727 2727 2727
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.810.468_ophthalmology.csv  Long:  2727
# H02.403.763.750_gynecology
# 1625 1625 1625
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.763.750_gynecology.csv  Long:  1625
# H02.403.429.730_rheumatology
# 1014 1014 1014
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.429.730_rheumatology.csv  Long:  1014
# H02.403.810.860_urology
# 6626 6626 6626
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.810.860_urology.csv  Long:  6626
# H02.403.810.526_otolaryngology
# 2398 2398 2398
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.810.526_otolaryngology.csv  Long:  2398
# H02.403.680.600_rehabilitation
# 325 325 325
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.680.600_rehabilitation.csv  Long:  325
# H02.403.429.580_nephrology
# 3777 3777 3777
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.429.580_nephrology.csv  Long:  3777
# H02.403.429.163_cardiology
# 11527 11527 11527
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.429.163_cardiology.csv  Long:  11527
# H02.403.810.425_neurosurgery
# 933 933 933
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.810.425_neurosurgery.csv  Long:  933
# H02.403.340.500_family_practice
# 363 363 363
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.340.500_family_practice.csv  Long:  363
# H02.403.680_physical_and_rehabilitation_medicine
# 23 23 23
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.680_physical_and_rehabilitation_medicine.csv  Long:  23
# H02.403.670_pediatrics
# 1795 1795 1795
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.670_pediatrics.csv  Long:  1795
# H02.403.810.788_surgery_plastic
# 320 320 320
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.810.788_surgery_plastic.csv  Long:  320
# H02.403.225_dermatology
# 6979 6979 6979
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.225_dermatology.csv  Long:  6979
# H02.403.429.323_endocrinology
# 4971 4971 4971
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.429.323_endocrinology.csv  Long:  4971
# H02.403.720.500_epidemiology
# 899 899 899
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.720.500_epidemiology.csv  Long:  899
# H02.403.740.500_nuclear_medicine
# 616 616 616
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.740.500_nuclear_medicine.csv  Long:  616
# H02.403.810.850_traumatology
# 3303 3303 3303
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.810.850_traumatology.csv  Long:  3303
# H02.403.670.500_perinatology
# 2120 2120 2120
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.670.500_perinatology.csv  Long:  2120
# H02.403.355_geriatrics
# 12884 12884 12884
# Guardado  ./dataframes/df_specialty_title_abstract_case_report/H02.403.355_geriatrics.csv  Long:  12884

# %% [markdown]
# # 3. Crear dataframe con seis columnas
# ### Directorio: df_specialty_ngram
# ### Columnas dataframe: (idpubmed, título-unigramas, título-bigramas, título-trigramas, abstract-unigramas, abstract-bigramas, abstract-trigramas)
#
# ## Procesamiento de texto:
#     1 Lowercase: pasar a minúscula si el término no es uppercase
#     2. Unigramas:
#         2.1 borrar puntuacion
#         2.2 borrar dígitos

# %%
import os
import pandas as pd
import os
import spacy
import ast
nlp = spacy.load('es_core_news_sm')
from nltk import everygrams
from nltk.corpus import stopwords
stop_words = set(stopwords.words('spanish')) 
import string

# %%
path_df_specialty_title_abstract = './pubmed_files/dataframes/df_specialty_title_abstract'
path_df_specialty_xgram_title_abstract = './pubmed_files/dataframes/df_specialty_ngram'

# %%
def change_to_lowercase(term):
    if not term.isupper():
        return term.lower()
    return term

# %%
def to_lowercase(list_terms):
    
    list_terms_new = []
    
    for term in list_terms:
        
        if type(term) == str:
             list_terms_new.append(change_to_lowercase(term))
                
        elif type(term) == tuple:
            new_tuple = ()
            
            for t in term:
                new_tuple = new_tuple + (change_to_lowercase(t),)
            list_terms_new.append(new_tuple)  
    
    #print("2",list_terms_new )
    return list_terms_new

# %%
def remove_stopword_punt_digit(list_tems):
    
    list_tems = [term for term in list_tems if not term in stop_words]
    list_tems = [term for term in list_tems if not term in set(string.punctuation)]
    list_tems = [term for term in list_tems if not term.isdigit() ] 
    
    #print("3", list_tems )
    return list_tems

# %%
def tokenize(text):
    list_tokens = []
    
    if type(text) == float:
        text = ''
    
    doc = nlp(text)
    for token in doc:
        list_tokens.append(token.text)
        
    return list_tokens

# %%
def obtain_grams(text, gram):
    list_tokens = tokenize(text)
    list_bigrams = list(everygrams(list_tokens, min_len=gram, max_len=gram))
    
    return list_bigrams

# %%
def create_new_df_xgrams(df):
    
    list_id = []
    list_ngram = []
    
    # Iteración por filas del DataFrame:
    for index, row in df.iterrows():
        
        file_id = row['id']
        abstract = row['abstract']
        title = row['title']
        
        title_unig = tokenize(title)
        title_big = obtain_grams(title ,2)
        title_trig = obtain_grams(title ,3)
        
        abstract_unig = tokenize(abstract)
        abstract_big = obtain_grams(abstract ,2)
        abstract_trig = obtain_grams(abstract ,3)
       
        ## procesamiento
        title_unig = remove_stopword_punt_digit(to_lowercase(title_unig))
        title_big = to_lowercase(title_big)
        title_trig = to_lowercase(title_trig)

        abstract_unig = remove_stopword_punt_digit(to_lowercase(abstract_unig))
        abstract_big = to_lowercase(abstract_big)
        abstract_trig = to_lowercase(abstract_trig)
        
        len_total = len(title_unig) + len(title_big) + len(title_trig) + len(abstract_unig) + len(abstract_big) + len(abstract_trig)
        
        list_id.extend([file_id] * len_total)
        list_ngram.extend(title_unig)
        list_ngram.extend(title_big)
        list_ngram.extend(title_trig)
        
        list_ngram.extend(abstract_unig)
        list_ngram.extend(abstract_big)
        list_ngram.extend(abstract_trig)
    
    new_df = pd.DataFrame ( { 'id': list_id, 
                         'ngram': list_ngram 
                         })
    return new_df

# %%
def read_df_specialties_title_abstract():

    list_df = os.listdir(path_df_specialty_title_abstract)
    for specialty_df in list_df:
        
        specialty_df = os.path.join(path_df_specialty_title_abstract, specialty_df)
        specialty_name_csv = specialty_df.split("/")[-1]
        
        df = pd.read_csv(specialty_df)
        print("Specialty: ", specialty_name_csv , ' --- Longitud del DF:', len(df))
        
        new_df = create_new_df_xgrams(df)
        
        file_out = os.path.join(path_df_specialty_xgram_title_abstract, specialty_name_csv)
        new_df.to_csv(file_out)
        print("Guardado ", file_out, ' Long: ', len(new_df))

# %%
read_df_specialties_title_abstract()
# Out:
# Specialty:  physical-and-rehabilitation-medicine.csv  --- Longitud del DF: 313
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/physical-and-rehabilitation-medicine.csv  Long:  18424
# Specialty:  reproductive-medicine.csv  --- Longitud del DF: 1116
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/reproductive-medicine.csv  Long:  41619
# Specialty:  geriatrics.csv  --- Longitud del DF: 37772
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/geriatrics.csv  Long:  1807467
# Specialty:  behavioral-medicine.csv  --- Longitud del DF: 16
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/behavioral-medicine.csv  Long:  535
# Specialty:  integrative-medicine.csv  --- Longitud del DF: 186
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/integrative-medicine.csv  Long:  13516
# Specialty:  psychiatry.csv  --- Longitud del DF: 3009
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/psychiatry.csv  Long:  139026
# Specialty:  aerospace-medicine.csv  --- Longitud del DF: 409
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/aerospace-medicine.csv  Long:  18838
# Specialty:  neurology.csv  --- Longitud del DF: 26017
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/neurology.csv  Long:  1210566
# Specialty:  social-medicine.csv  --- Longitud del DF: 1561
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/social-medicine.csv  Long:  112509
# Specialty:  dermatology.csv  --- Longitud del DF: 10753
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/dermatology.csv  Long:  341499
# Specialty:  disaster-medicine.csv  --- Longitud del DF: 20
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/disaster-medicine.csv  Long:  3422
# Specialty:  specialties,-surgical.csv  --- Longitud del DF: 85
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/specialties,-surgical.csv  Long:  4521
# Specialty:  venereology.csv  --- Longitud del DF: 5171
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/venereology.csv  Long:  203677
# Specialty:  adolescent-medicine.csv  --- Longitud del DF: 99
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/adolescent-medicine.csv  Long:  5520
# Specialty:  regenerative-medicine.csv  --- Longitud del DF: 199
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/regenerative-medicine.csv  Long:  8345
# Specialty:  anesthesiology.csv  --- Longitud del DF: 2346
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/anesthesiology.csv  Long:  90423
# Specialty:  genetics,-medical.csv  --- Longitud del DF: 6937
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/genetics,-medical.csv  Long:  254309
# Specialty:  radiology.csv  --- Longitud del DF: 2375
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/radiology.csv  Long:  90068
# Specialty:  internal-medicine.csv  --- Longitud del DF: 5908
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/internal-medicine.csv  Long:  299070
# Specialty:  .~lock.physical-and-rehabilitation-medicine.csv#  --- Longitud del DF: 0
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/.~lock.physical-and-rehabilitation-medicine.csv#  Long:  0
# Specialty:  hospital-medicine.csv  --- Longitud del DF: 53
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/hospital-medicine.csv  Long:  1059
# Specialty:  community-medicine.csv  --- Longitud del DF: 332
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/community-medicine.csv  Long:  12176
# Specialty:  global-health.csv  --- Longitud del DF: 1733
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/global-health.csv  Long:  76004
# Specialty:  molecular-medicine.csv  --- Longitud del DF: 1249
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/molecular-medicine.csv  Long:  53214
# Specialty:  geography,-medical.csv  --- Longitud del DF: 43
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/geography,-medical.csv  Long:  2484
# Specialty:  emergency-medicine.csv  --- Longitud del DF: 178
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/emergency-medicine.csv  Long:  39843
# Specialty:  vaccinology.csv  --- Longitud del DF: 33
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/vaccinology.csv  Long:  1948
# Specialty:  forensic-medicine.csv  --- Longitud del DF: 364
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/forensic-medicine.csv  Long:  19852
# Specialty:  sports-medicine.csv  --- Longitud del DF: 348
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/sports-medicine.csv  Long:  18511
# Specialty:  pathology.csv  --- Longitud del DF: 21916
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/pathology.csv  Long:  844014
# Specialty:  theranostic-nanomedicine.csv  --- Longitud del DF: 0
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/theranostic-nanomedicine.csv  Long:  0
# Specialty:  military-medicine.csv  --- Longitud del DF: 258
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/military-medicine.csv  Long:  7547
# Specialty:  bariatric-medicine.csv  --- Longitud del DF: 280
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/bariatric-medicine.csv  Long:  27785
# Specialty:  palliative-medicine.csv  --- Longitud del DF: 559
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/palliative-medicine.csv  Long:  23584
# Specialty:  addiction-medicine.csv  --- Longitud del DF: 0
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/addiction-medicine.csv  Long:  0
# Specialty:  pediatrics.csv  --- Longitud del DF: 6983
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/pediatrics.csv  Long:  486540
# Specialty:  allergy-and-immunology.csv  --- Longitud del DF: 474
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/allergy-and-immunology.csv  Long:  50969
# Specialty:  tropical-medicine.csv  --- Longitud del DF: 1324
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/tropical-medicine.csv  Long:  51771
# Specialty:  osteopathic-medicine.csv  --- Longitud del DF: 12
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/osteopathic-medicine.csv  Long:  238
# Specialty:  telemedicine.csv  --- Longitud del DF: 244
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/telemedicine.csv  Long:  13448
# Specialty:  general-practice.csv  --- Longitud del DF: 2184
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/general-practice.csv  Long:  126969
# Specialty:  public-health.csv  --- Longitud del DF: 12008
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/public-health.csv  Long:  828490
# Specialty:  clinical-medicine.csv  --- Longitud del DF: 15923
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/clinical-medicine.csv  Long:  492348
# Specialty:  naval-medicine.csv  --- Longitud del DF: 170
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/naval-medicine.csv  Long:  7543
# Specialty:  wilderness-medicine.csv  --- Longitud del DF: 6
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/wilderness-medicine.csv  Long:  187
# Specialty:  travel-medicine.csv  --- Longitud del DF: 18
# Guardado  ./pubmed_files/dataframes/df_specialty_ngram/travel-medicine.csv  Long:  485

# %% [markdown]
# # 4 Crear otro tipo de estructura

# %%
import os
import pandas as pd
import pickle

# %%
path_df_specialty_xgram_title_abstract = './pubmed_files/dataframes/df_specialty_ngram'

# %%
def read_df_specialties_grams():
    
    dic_final = {}

    list_df = os.listdir(path_df_specialty_xgram_title_abstract)
    
    for specialty_df in list_df:
        
        dic_specialty = {}
        
        specialty_name_csv = specialty_df
        
        df = pd.read_csv(os.path.join(path_df_specialty_xgram_title_abstract, specialty_df))
        
        print("Specialty: ", specialty_name_csv , ' --- Longitud del DF:', len(df))
        
        list_docs = []
        dic_terms = {}
        
        # Iteración por filas del DataFrame:
        for index, row in df.iterrows():

            file_id = row['id']
            ngram = row['ngram']
            
            list_docs.append(file_id)
            dic_terms.setdefault(ngram, []).append(file_id)
            
        dic_specialty['terms'] = dic_terms
        dic_specialty['docs'] = list(set(list_docs))
        
        print("Nº de términos en la especialidad:", len(dic_specialty['terms']))
        print("Nº de doc en la especialidad:", len(dic_specialty['docs']))
        dic_final[specialty_name_csv] = dic_specialty
               
    with open('dic_specialties.pkl', 'wb') as f:
        pickle.dump(dic_final, f)

# %%
read_df_specialties_grams()
# Out:
# Specialty:  physical-and-rehabilitation-medicine.csv  --- Longitud del DF: 18424
# Nº de términos en la especialidad: 13183
# Nº de doc en la especialidad: 276
# Specialty:  reproductive-medicine.csv  --- Longitud del DF: 41619
# Nº de términos en la especialidad: 25751
# Nº de doc en la especialidad: 1070
# Specialty:  geriatrics.csv  --- Longitud del DF: 1807467
# Nº de términos en la especialidad: 634311
# Nº de doc en la especialidad: 35324
# Specialty:  behavioral-medicine.csv  --- Longitud del DF: 535
# Nº de términos en la especialidad: 482
# Nº de doc en la especialidad: 15
# Specialty:  integrative-medicine.csv  --- Longitud del DF: 13516
# Nº de términos en la especialidad: 10486
# Nº de doc en la especialidad: 165
# Specialty:  psychiatry.csv  --- Longitud del DF: 139026
# Nº de términos en la especialidad: 75584
# Nº de doc en la especialidad: 2834
# Specialty:  aerospace-medicine.csv  --- Longitud del DF: 18838
# Nº de términos en la especialidad: 13046
# Nº de doc en la especialidad: 381
# Specialty:  neurology.csv  --- Longitud del DF: 1210566
# Nº de términos en la especialidad: 472286
# Nº de doc en la especialidad: 23862
# Specialty:  social-medicine.csv  --- Longitud del DF: 112509
# Nº de términos en la especialidad: 65229
# Nº de doc en la especialidad: 1491
# Specialty:  dermatology.csv  --- Longitud del DF: 341499
# Nº de términos en la especialidad: 166153
# Nº de doc en la especialidad: 9413
# Specialty:  disaster-medicine.csv  --- Longitud del DF: 3422
# Nº de términos en la especialidad: 2592
# Nº de doc en la especialidad: 18
# Specialty:  specialties,-surgical.csv  --- Longitud del DF: 4521
# Nº de términos en la especialidad: 3644
# Nº de doc en la especialidad: 69
# Specialty:  venereology.csv  --- Longitud del DF: 203677
# Nº de términos en la especialidad: 83295
# Nº de doc en la especialidad: 4940
# Specialty:  adolescent-medicine.csv  --- Longitud del DF: 5520
# Nº de términos en la especialidad: 4280
# Nº de doc en la especialidad: 89
# Specialty:  regenerative-medicine.csv  --- Longitud del DF: 8345
# Nº de términos en la especialidad: 6667
# Nº de doc en la especialidad: 180
# Specialty:  anesthesiology.csv  --- Longitud del DF: 90423
# Nº de términos en la especialidad: 49836
# Nº de doc en la especialidad: 2139
# Specialty:  genetics,-medical.csv  --- Longitud del DF: 254309
# Nº de términos en la especialidad: 128402
# Nº de doc en la especialidad: 6357
# Specialty:  radiology.csv  --- Longitud del DF: 90068
# Nº de términos en la especialidad: 53464
# Nº de doc en la especialidad: 2060
# Specialty:  internal-medicine.csv  --- Longitud del DF: 299070
# Nº de términos en la especialidad: 133803
# Nº de doc en la especialidad: 5475
# Specialty:  hospital-medicine.csv  --- Longitud del DF: 1059
# Nº de términos en la especialidad: 961
# Nº de doc en la especialidad: 35
# Specialty:  community-medicine.csv  --- Longitud del DF: 12176
# Nº de términos en la especialidad: 7194
# Nº de doc en la especialidad: 325
# Specialty:  global-health.csv  --- Longitud del DF: 76004
# Nº de términos en la especialidad: 44433
# Nº de doc en la especialidad: 1569
# Specialty:  molecular-medicine.csv  --- Longitud del DF: 53214
# Nº de términos en la especialidad: 35579
# Nº de doc en la especialidad: 1168
# Specialty:  geography,-medical.csv  --- Longitud del DF: 2484
# Nº de términos en la especialidad: 2176
# Nº de doc en la especialidad: 32
# Specialty:  emergency-medicine.csv  --- Longitud del DF: 39843
# Nº de términos en la especialidad: 25778
# Nº de doc en la especialidad: 168
# Specialty:  vaccinology.csv  --- Longitud del DF: 1948
# Nº de términos en la especialidad: 1579
# Nº de doc en la especialidad: 31
# Specialty:  forensic-medicine.csv  --- Longitud del DF: 19852
# Nº de términos en la especialidad: 14492
# Nº de doc en la especialidad: 346
# Specialty:  sports-medicine.csv  --- Longitud del DF: 18511
# Nº de términos en la especialidad: 13230
# Nº de doc en la especialidad: 321
# Specialty:  pathology.csv  --- Longitud del DF: 844014
# Nº de términos en la especialidad: 367232
# Nº de doc en la especialidad: 20364
# Specialty:  theranostic-nanomedicine.csv  --- Longitud del DF: 0
# Nº de términos en la especialidad: 0
# Nº de doc en la especialidad: 0
# Specialty:  military-medicine.csv  --- Longitud del DF: 7547
# Nº de términos en la especialidad: 5731
# Nº de doc en la especialidad: 214
# Specialty:  bariatric-medicine.csv  --- Longitud del DF: 27785
# Nº de términos en la especialidad: 16713
# Nº de doc en la especialidad: 236
# Specialty:  palliative-medicine.csv  --- Longitud del DF: 23584
# Nº de términos en la especialidad: 15292
# Nº de doc en la especialidad: 517
# Specialty:  addiction-medicine.csv  --- Longitud del DF: 0
# Nº de términos en la especialidad: 0
# Nº de doc en la especialidad: 0
# Specialty:  pediatrics.csv  --- Longitud del DF: 486540
# Nº de términos en la especialidad: 226273
# Nº de doc en la especialidad: 6516
# Specialty:  allergy-and-immunology.csv  --- Longitud del DF: 50969
# Nº de términos en la especialidad: 30878
# Nº de doc en la especialidad: 452
# Specialty:  tropical-medicine.csv  --- Longitud del DF: 51771
# Nº de términos en la especialidad: 30803
# Nº de doc en la especialidad: 1206
# Specialty:  osteopathic-medicine.csv  --- Longitud del DF: 238
# Nº de términos en la especialidad: 230
# Nº de doc en la especialidad: 9
# Specialty:  telemedicine.csv  --- Longitud del DF: 13448
# Nº de términos en la especialidad: 9605
# Nº de doc en la especialidad: 224
# Specialty:  general-practice.csv  --- Longitud del DF: 126969
# Nº de términos en la especialidad: 72667
# Nº de doc en la especialidad: 2060
# Specialty:  public-health.csv  --- Longitud del DF: 828490
# Nº de términos en la especialidad: 342229
# Nº de doc en la especialidad: 11310
# Specialty:  clinical-medicine.csv  --- Longitud del DF: 492348
# Nº de términos en la especialidad: 191278
# Nº de doc en la especialidad: 15588
# Specialty:  naval-medicine.csv  --- Longitud del DF: 7543
# Nº de términos en la especialidad: 5936
# Nº de doc en la especialidad: 163
# Specialty:  wilderness-medicine.csv  --- Longitud del DF: 187
# Nº de términos en la especialidad: 177
# Nº de doc en la especialidad: 6
# Specialty:  travel-medicine.csv  --- Longitud del DF: 485
# Nº de términos en la especialidad: 455
# Nº de doc en la especialidad: 16

# %% [markdown]
# ### Prueba varios términos en especialidad:

# %%
def deserialize_object(path):
    pickle_in = open(path,"rb")
    obj = pickle.load(pickle_in)
    pickle_in.close()
    print("Cargado el objeto", path.split("/")[- 1])
    return obj

# %%
path_dic = 'dic_specialties.pkl'
dic = deserialize_object(path_dic)
# Out:
# Cargado el objeto dic_specialties.pkl
# [26089279, 24008534, 25690141, 25619797, 25619797, 29428270, 29428270, 26032996, 25707329, 25707329, 24119683, 22424972, 22424972, 15839820, 29616681, 29616681, 29616681, 29616681, 29616681]

# %%
print(dic['vaccinology.csv']['terms']["('de', 'la')"]) # 19 veces -> correcto
print(dic['vaccinology.csv']['terms']["vacuna"]) # 13 veces -> correcto

# %%
print(dic['vaccinology.csv']['docs'])
# Out:
# [16756864, 16173697, 24119683, 22424972, 19100177, 23684502, 31148440, 25690141, 23540383, 30031656, 29616681, 11188908, 29428270, 26341041, 25172540, 26089279, 25707329, 12106566, 24294728, 15384265, 26613832, 22948426, 15839820, 30262223, 25619797, 24008534, 23416026, 26032996, 24582127, 24399343, 23807343]
