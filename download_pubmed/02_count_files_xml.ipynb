# %% [markdown]
# ## contar nº docs por especialidad
# ## contar nº cases reports por especialidad

# %%
import xml.etree.ElementTree as ET
import os

# %%
def get_lists_pmid_title_abstract(root):
    
    list_pmid = []
    list_title = []
    list_abstract = []
    
    for PubmedArticle in root.findall('PubmedArticle'):
        
        pmid = ''
        title_spa = ''
        abstract_spa = ''
        
        for MedlineCitation in PubmedArticle.findall('MedlineCitation'):
            pmid = MedlineCitation.find('PMID').text
        
            for Article in MedlineCitation.findall('Article'):
                if not Article.find('VernacularTitle') is None:              
                    title_spa = Article.find('VernacularTitle').text
            
            for OtherAbstract in MedlineCitation.findall('OtherAbstract'):
                abstrac_lang = OtherAbstract.get('Language')
                                
                if abstrac_lang == 'spa':
                    for AbstractText in OtherAbstract.findall('AbstractText'):
                        if not AbstractText.text is None:
                            abstract_spa = abstract_spa + AbstractText.text + ' '
         
        list_pmid.append(pmid)
        list_title.append(title_spa)
        list_abstract.append(abstract_spa)
        
    
    
    return list_pmid, list_title, list_abstract

# %%
def read_xml_file(file_xml):
    tree = ET.parse(file_xml)
    root = tree.getroot()
    return root

# %%
def read_path_specialties_xml(path_xmls, path_casesreports_xml):
    for root, dirs, list_files in os.walk(path_xmls):
        list_files.sort(reverse = True)
        for specialty in list_files:
            
            print("ESPECIALIDAD\t# PMID\t# TITLES\t# ABSTRACT\t# PMID-CASES-REPORT\t# TITLES-CASES-REPORT\t# ABSTRACT-CASES-REPORT")
            if specialty.endswith('.xml'):
            
                #print(specialty)
                
                # contar ficheros sin cases reports
                xml_data = read_xml_file(os.path.join(path_xmls ,specialty))
                list_pmid, list_title, list_abstract = get_lists_pmid_title_abstract(xml_data)
                
                # contar cases reports
                xml_data = read_xml_file(os.path.join(path_casesreports_xml ,specialty))
                list_pmid_cr, list_title_cr, list_abstract_cr = get_lists_pmid_title_abstract(xml_data)
                
                print("{}\t{}\t{}\t{}\t{}\t{}\t{}".format(len(list_pmid), len(list_title), len(list_abstract), len(list_pmid_cr), len(list_title_cr), len(list_abstract_cr)))

# %%
path_files_xmls = 'specialties_subespecialties_xml'
path_casesreports_xml = 'specialties_subespecialties_case_report_xml'

read_path_specialties_xml(path_files_xmls, path_casesreports_xml)
# Out:
# H02.403.959_wilderness_medicine.xml
# 	Nº de PMID recibidos: 0, nº sin repetidos: 0
# 	Nº de títulos obtenidos: 0
# 	Nº de abstract obtenidos: 0
# 	CASES REPORT - Nº de PMID recibidos: 0, nº sin repetidos: 0
# 	CASES REPORT - Nº de títulos obtenidos: 0
# 	CASES REPORT - Nº de abstract obtenidos: 0
# H02.403.909_venereology.xml
# 	Nº de PMID recibidos: 5185, nº sin repetidos: 5185
# 	Nº de títulos obtenidos: 4910
# 	Nº de abstract obtenidos: 51
# 	CASES REPORT - Nº de PMID recibidos: 1660, nº sin repetidos: 1660
# 	CASES REPORT - Nº de títulos obtenidos: 1592
# 	CASES REPORT - Nº de abstract obtenidos: 10
# H02.403.879_tropical_medicine.xml
# 	Nº de PMID recibidos: 1008, nº sin repetidos: 1008
# 	Nº de títulos obtenidos: 972
# 	Nº de abstract obtenidos: 18
# 	CASES REPORT - Nº de PMID recibidos: 91, nº sin repetidos: 91
# 	CASES REPORT - Nº de títulos obtenidos: 89
# 	CASES REPORT - Nº de abstract obtenidos: 3
# H02.403.850_travel_medicine.xml
# 	Nº de PMID recibidos: 9, nº sin repetidos: 9
# 	Nº de títulos obtenidos: 8
# 	Nº de abstract obtenidos: 1
# 	CASES REPORT - Nº de PMID recibidos: 1, nº sin repetidos: 1
# 	CASES REPORT - Nº de títulos obtenidos: 1
# 	CASES REPORT - Nº de abstract obtenidos: 1
# H02.403.845_theranostic_nanomedicine.xml
# 	Nº de PMID recibidos: 0, nº sin repetidos: 0
# 	Nº de títulos obtenidos: 0
# 	Nº de abstract obtenidos: 0
# 	CASES REPORT - Nº de PMID recibidos: 0, nº sin repetidos: 0
# 	CASES REPORT - Nº de títulos obtenidos: 0
# 	CASES REPORT - Nº de abstract obtenidos: 0
# H02.403.840_telemedicine.xml
# 	Nº de PMID recibidos: 246, nº sin repetidos: 246
# 	Nº de títulos obtenidos: 224
# 	Nº de abstract obtenidos: 13
# 	CASES REPORT - Nº de PMID recibidos: 4, nº sin repetidos: 4
# 	CASES REPORT - Nº de títulos obtenidos: 4
# 	CASES REPORT - Nº de abstract obtenidos: 1
# H02.403.840.850_telerehabilitation.xml
# 	Nº de PMID recibidos: 4, nº sin repetidos: 4
# 	Nº de títulos obtenidos: 4
# 	Nº de abstract obtenidos: 2
# 	CASES REPORT - Nº de PMID recibidos: 0, nº sin repetidos: 0
# 	CASES REPORT - Nº de títulos obtenidos: 0
# 	CASES REPORT - Nº de abstract obtenidos: 0
# H02.403.840.700_teleradiology.xml
# 	Nº de PMID recibidos: 9, nº sin repetidos: 9
# 	Nº de títulos obtenidos: 9
# 	Nº de abstract obtenidos: 1
# 	CASES REPORT - Nº de PMID recibidos: 1, nº sin repetidos: 1
# 	CASES REPORT - Nº de títulos obtenidos: 1
# 	CASES REPORT - Nº de abstract obtenidos: 1
# H02.403.840.600_telepathology.xml
# 	Nº de PMID recibidos: 4, nº sin repetidos: 4
# 	Nº de títulos obtenidos: 4
# 	Nº de abstract obtenidos: 1
# 	CASES REPORT - Nº de PMID recibidos: 0, nº sin repetidos: 0
# 	CASES REPORT - Nº de títulos obtenidos: 0
# 	CASES REPORT - Nº de abstract obtenidos: 0
# H02.403.830_sports_medicine.xml
# 	Nº de PMID recibidos: 352, nº sin repetidos: 352
# 	Nº de títulos obtenidos: 320
# 	Nº de abstract obtenidos: 18
# 	CASES REPORT - Nº de PMID recibidos: 107, nº sin repetidos: 107
# 	CASES REPORT - Nº de títulos obtenidos: 103
# 	CASES REPORT - Nº de abstract obtenidos: 4
# H02.403.830.500_sports_nutritional_sciences.xml
# 	Nº de PMID recibidos: 4, nº sin repetidos: 4
# 	Nº de títulos obtenidos: 4
# 	Nº de abstract obtenidos: 4
# 	CASES REPORT - Nº de PMID recibidos: 0, nº sin repetidos: 0
# 	CASES REPORT - Nº de títulos obtenidos: 0
# 	CASES REPORT - Nº de abstract obtenidos: 0
# H02.403.810_specialties_surgical.xml
# 	Nº de PMID recibidos: 83, nº sin repetidos: 83
# 	Nº de títulos obtenidos: 68
# 	Nº de abstract obtenidos: 6
# 	CASES REPORT - Nº de PMID recibidos: 0, nº sin repetidos: 0
# 	CASES REPORT - Nº de títulos obtenidos: 0
# 	CASES REPORT - Nº de abstract obtenidos: 0
# H02.403.810.796_surgical_oncology.xml
# 	Nº de PMID recibidos: 28, nº sin repetidos: 28
# 	Nº de títulos obtenidos: 24
# 	Nº de abstract obtenidos: 6
# 	CASES REPORT - Nº de PMID recibidos: 11, nº sin repetidos: 11
# 	CASES REPORT - Nº de títulos obtenidos: 9
# 	CASES REPORT - Nº de abstract obtenidos: 4
# H02.403.810.788_surgery_plastic.xml
# 	Nº de PMID recibidos: 1388, nº sin repetidos: 1388
# 	Nº de títulos obtenidos: 1167
# 	Nº de abstract obtenidos: 48
# 	CASES REPORT - Nº de PMID recibidos: 362, nº sin repetidos: 362
# 	CASES REPORT - Nº de títulos obtenidos: 321
# 	CASES REPORT - Nº de abstract obtenidos: 29
# H02.403.810.526_otolaryngology.xml
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-5fced14e6bbc> in <module>
#       2 path_casesreports_xml = 'specialties_subespecialties_case_report_xml'
#       3
# ----> 4 read_path_specialties_xml(path_files_xmls, path_casesreports_xml)
#
# <ipython-input-20-02f02c7960cd> in read_path_specialties_xml(path_xmls, path_casesreports_xml)
#       9
#      10                 # contar ficheros sin cases reports
# ---> 11                 xml_data = read_xml_file(os.path.join(path_xmls ,specialty))
#      12                 list_pmid, list_title, list_abstract = get_lists_pmid_title_abstract(xml_data)
#      13
#
# <ipython-input-4-abcbc37fa63b> in read_xml_file(file_xml)
#       1 def read_xml_file(file_xml):
# ----> 2     tree = ET.parse(file_xml)
#       3     root = tree.getroot()
#       4     return root
#
# /usr/lib/python3.5/xml/etree/ElementTree.py in parse(source, parser)
#    1182     """
#    1183     tree = ElementTree()
# -> 1184     tree.parse(source, parser)
#    1185     return tree
#    1186
#
# /usr/lib/python3.5/xml/etree/ElementTree.py in parse(self, source, parser)
#     594                     # It can be used to parse the whole source without feeding
#     595                     # it with chunks.
# --> 596                     self._root = parser._parse_whole(source)
#     597                     return self._root
#     598             while True:
#
# KeyboardInterrupt:
